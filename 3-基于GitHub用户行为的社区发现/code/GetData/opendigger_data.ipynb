# %%
from select import select
from odps import ODPS
from odps import options
from odps.df import DataFrame
import pandas as pd
import numpy as np

# %%
import multiprocessing

# %%
n_process = multiprocessing.cpu_count()

# %%
n_process
# Out:
# 8

# %%
# 不要泄露key
ACCESS_ID = '*************'
SECRET_ACCESS_KEY = '****************'
ODPS_PROJECT = 'OpenDigger_prod_dev'
ODPS_ENDPOINT = 'http://service.cn-shanghai.maxcompute.aliyun.com/api'
# ACCESS_ID = 'LTAI5tSjrYp6JDW2bbiTdegU'
# SECRET_ACCESS_KEY = 'OE6JbSqOZUey5fzr9Wg6fuYYKvslZx'
# 创建odps实例
o = ODPS(ACCESS_ID, SECRET_ACCESS_KEY,
         project=ODPS_PROJECT, endpoint=ODPS_ENDPOINT)
options.tunnel.limit_instance_tunnel = False
options.read_timeout = 3600000

users = DataFrame(o.get_table('ods_github_users'))
print(users.dtypes)

github_log = DataFrame(o.get_table('ods_github_log'))
print(github_log.dtypes)
# Out:
# odps.Schema {
#   login                     string
#   created_at                date
#   database_id               int64
#   location                  string
#   company                   string
#   bio                       string
#   is_employee               boolean
#   email                     string
#   infoname                  string
#   followers                 string
#   following                 string
#   time                      date
#   name                      string
#   lastupdatedat             date
#   nextupdateat              date
# }
#
# odps.Schema {
#   id                                                                          string
#   type                                                                        string
#   action                                                                      string
#   actor_id                                                                    int64
# ...

# %%
user_head = users.head(20)
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()

# %%
user_head
# Out:
# DFViewWidget()
#                     login  created_at  database_id           location  \
# 0               LombiqBot  2014-08-21      8517910  Budapest, Hungary
# 1               LombiqBot  2014-08-21      8517910  Budapest, Hungary
# 2               LombiqBot  2014-08-21      8517910  Budapest, Hungary
# 3         direwolf-github  2015-02-02     10810283               None
# 4         direwolf-github  2015-02-02     10810283               None
# 5         direwolf-github  2015-02-02     10810283               None
# 6              commit-b0t  2020-11-07     74113347             GitHub
# 7              commit-b0t  2020-11-07     74113347             GitHub
# 8              commit-b0t  2020-11-07     74113347             GitHub
# 9            renovate-bot  2017-01-17     25180681               None
# 10           renovate-bot  2017-01-17     25180681               None
# 11           renovate-bot  2017-01-17     25180681               None
# ...

# %%
github_log_head = github_log.head(20)
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()

# %%
github_log_head
# Out:
# DFViewWidget()
#             id          type     action  actor_id     actor_login   repo_id  \
# 0   2511623267   CreateEvent              4560264     marcy-terui  29237728
# 1   2511625593   CreateEvent              4560264     marcy-terui  29237728
# 2   2511651426     PushEvent              4560264     marcy-terui  29237728
# 3   2511636091   CreateEvent              4560264     marcy-terui  29237984
# 4   2511636864   CreateEvent              4560264     marcy-terui  29237984
# 5   2511642712     PushEvent              4560264     marcy-terui  29237984
# 6   2514256150    WatchEvent    started   4560264     marcy-terui  29281918
# 7   2542625675   CreateEvent              4560266          dougrt  10345130
# 8   2545080122   CreateEvent              4560266          dougrt  10345130
# 9   2545199738   CreateEvent              4560266          dougrt  10345130
# 10  2543050048   DeleteEvent              4560266          dougrt  10345130
# ...

# %%
type(users)
# Out:
# odps.df.core.DataFrame

# %%
users.distinct('is_employee')
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()
# DFViewWidget()
#    is_employee
# 0        False
# 1         True

# %%
users['followers']
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()
# DFViewWidget()
#                                                 followers
# 0       50567111,61306948,60854565,57724193,55095689,5...
# 1       50567111,61306948,60854565,57724193,55095689,5...
# 2       50567111,61306948,60854565,57724193,55095689,5...
# 3                     57059290,35817050,56658371,45868471
# 4                     57059290,35817050,56658371,45868471
# ...                                                   ...
# 618237  48577694,72131649,42285463,72012602,59365947,6...
# 618238  93073000,38338565,18473413,48854566,32595111,2...
# 618239                                           79547580
# 618240                                               None
# 618241  61415422,89124575,95914239,95329733,95328946,9...
#
# [618242 rows x 1 columns]

# %%
users[0:5000000]
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()
# DFViewWidget()
#                     login  created_at  database_id                   location  \
# 0               LombiqBot  2014-08-21      8517910          Budapest, Hungary
# 1               LombiqBot  2014-08-21      8517910          Budapest, Hungary
# 2               LombiqBot  2014-08-21      8517910          Budapest, Hungary
# 3         direwolf-github  2015-02-02     10810283                       None
# 4         direwolf-github  2015-02-02     10810283                       None
# ...                   ...         ...          ...                        ...
# 618237            Enjay27  2016-11-08     23338687                      Korea
# 618238             denllx  2018-08-14     42374096                       None
# 618239           bkiscool  2017-11-23     33919755                       None
# 618240  NguyenLeTienTrien  2021-09-04     90084675                    Vietnam
# ...

# %%
users_pandas = users[0:5000000].to_pandas()
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()

# %%
users_pandas.to_csv('users_pandas.csv')

# %%
log_pandas = github_log[0:8000000].to_pandas()
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()

# %%
log_pandas.to_csv('github_log.csv')

# %%
github_log[]

# %%
github_log_pandas = github_log.to_pandas()
github_log_pandas.to_csv('github_logs.csv')

# %%
github_log_pandas = github_log.to_pandas()

# %%
github_log.dtypes

# %%
github_log_data = github_log.head(600000)

# %%
github_log_pandas = github_log_data.to_pandas()
github_log_pandas.to_csv('github_logs.csv')
